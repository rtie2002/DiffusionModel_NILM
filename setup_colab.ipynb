# %% [markdown]
# # DiffusionModel_NILM - Google Colab Setup
# Run this notebook in Google Colab to train the Diffusion Model with GPU

# %%
# 1. Check GPU availability
# !nvidia-smi

# %%
# 2. Clone repository (replace with your GitHub URL)
# !git clone https://github.com/your-username/DiffusionModel_NILM.git
# %cd DiffusionModel_NILM

# %%
# 3. Install dependencies
# !pip install -r requirements.txt

# %%
# 4. Upload your data (if not in repo)
from google.colab import files
# Uncomment if you need to upload kettle.csv
# uploaded = files.upload()
# !mkdir -p Data/datasets
# !mv kettle.csv Data/datasets/

# %%
# 5. Start training
# !python main.py --config Config/kettle.yaml --train

# %%
# 6. Generate samples (after training)
# !python main.py --config Config/kettle.yaml --sample 2000

# %%
# 7. Download results
from google.colab import files
# !zip -r results.zip .Checkpoints OUTPUT
files.download('results.zip')
